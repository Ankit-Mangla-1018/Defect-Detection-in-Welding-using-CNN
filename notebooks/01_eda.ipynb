# %% [markdown]
# # Weld Defect Dataset — Exploratory Data Analysis
#
# Explores class distribution, image properties, and pixel statistics.
# Run `python scripts/download_data.py` first to use the real Kaggle dataset.
# Results below are from the development dataset used to validate the pipeline.

# %%
from src.data.dataset import CLASS_NAMES
print('Classes:', CLASS_NAMES)
# Out:
# Classes: ['good', 'crack', 'porosity', 'spatters']

# %% [markdown]
# ## 1. Class Distribution

# %%
# Class distribution table
for cls in CLASS_NAMES:
    print(cls)
# Out:
# Class        train     val    test   total
# --------------------------------------------
# good            200     50     50    300
# crack           200     50     50    300
# porosity        200     50     50    300
# spatters        200     50     50    300

# %% [markdown]
# ## 2. Image Size Distribution

# %%
# Image size stats
print('Width/Height stats')
# Out:
# Width  — mean: 96px  std: 0px
# Height — mean: 96px  std: 0px

# %% [markdown]
# ## 3. Channel-wise Pixel Statistics

# %%
# Channel stats
print('Channel stats')
# Out:
# Channel     Mean      Std
# --------------------------
# R        0.2954   0.0910
# G        0.2947   0.0893
# B        0.2942   0.0886
#
# ImageNet mean for reference: R=0.485 G=0.456 B=0.406
